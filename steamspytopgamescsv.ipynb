# %%
import pandas as pd

# %%
spy_data = pd.read_csv("SteamSpy_data.csv")

# %%
spy_data
# Out:
#       #                                            Game Release date    Price  \
# 0     1                              Crusader Kings III     1-Sep-20  $49.99
# 1     2                                       Craftopia     4-Sep-20  $22.49
# 2     3                                    Iron Harvest     1-Sep-20  $49.99
# 3     4                                  DEEMO -Reborn-     3-Sep-20  $24.99
# 4     5                        Control Ultimate Edition    27-Aug-20  $31.99
# ..  ...                                             ...          ...      ...
# 95   96                              Double Kick Heroes    13-Aug-20  $19.99
# 96   97                                   Windy Kingdom    11-Aug-20  $14.99
# 97   98                                    Ever Forward    13-Aug-20  $14.99
# 98   99  Absolute Territory: The Space Combat Simulator    31-Aug-20  $17.09
# 99  100                                    The Infected     7-Aug-20  $13.99
#
# ...
