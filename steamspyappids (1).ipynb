# %%
from bs4 import BeautifulSoup as bs
import requests
import os
import re

# %%
filepath = os.path.join("steam_db_top_1000.html")
with open(filepath, encoding = 'utf-8') as file:
        html = file.read()

# %%
soup = bs(html, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!-- saved from url=(0043)https://steamdb.info/stats/gameratings/?all -->
# <html class="dark-mode" lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><style class="vjs-styles-defaults">
#       .video-js {
#         width: 300px;
#         height: 150px;
#       }
#
#       .vjs-fluid {
#         padding-top: 56.25%
#       }
#     </style>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Top Rated Games on Steam · SteamDB</title>
# <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
# <link href="https://cdn.cloudflare.steamstatic.com/" rel="preconnect"/>
# <link crossorigin="anonymous" href="./steam_db_top_1000_files/css" rel="stylesheet"/>
# ...

# %%
appid_list = []
for a in soup.find_all('a', href=re.compile("app")):
    print(a['href'])
    appid = str(a["href"])
    appid_list.append(a)
# Out:
# https://steamdb.info/apps/
# https://steamdb.info/apps/
# https://steamdb.info/app/730/
# https://steamdb.info/app/730/
# https://steamdb.info/app/570/
# https://steamdb.info/app/570/
# https://steamdb.info/app/578080/
# https://steamdb.info/app/578080/
# https://steamdb.info/app/271590/
# https://steamdb.info/app/271590/
# https://steamdb.info/app/359550/
# https://steamdb.info/app/359550/
# https://steamdb.info/app/440/
# https://steamdb.info/app/440/
# https://steamdb.info/app/4000/
# https://steamdb.info/app/4000/
# https://steamdb.info/app/105600/
# https://steamdb.info/app/105600/
# https://steamdb.info/app/252950/
# https://steamdb.info/app/252950/
# https://steamdb.info/app/292030/
# https://steamdb.info/app/292030/
# https://steamdb.info/app/252490/
# https://steamdb.info/app/252490/
# https://steamdb.info/app/218620/
# https://steamdb.info/app/218620/
# https://steamdb.info/app/550/
# https://steamdb.info/app/550/
# https://steamdb.info/app/304930/
# ...

# %%
appid_list
# Out:
# [<a href="https://steamdb.info/apps/">Apps</a>,
# ...
